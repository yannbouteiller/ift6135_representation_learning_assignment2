# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/My Drive/AaronTP2/Khalifa_latest/Final
# Out:
# /content/gdrive/My Drive/AaronTP2/Khalifa_latest/Final

# %% [markdown]
# # Question 5.1

# %%
# !python 5_1/q5_1.py --model=RNN --batch_size=2028
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# Current Step = 0
# tcmalloc: large alloc 2839207936 bytes == 0x16564000 @  0x7fd2ce279b6b 0x7fd2ce299379 0x7fd28139ed36 0x7fd28139f130 0x7fd2813a284c 0x7fd2811951df 0x7fd281294891 0x7fd281193470 0x7fd2c0be18f4 0x5030d5 0x506859 0x501945 0x591461 0x59ebbe 0x507c17 0x504c28 0x501b2e 0x591461 0x59ebbe 0x54d4e2 0x5a730c 0x503073 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x506393 0x634d52 0x634e0a 0x6385c8

# %%
# !python 5_1/q5_1.py --model=GRU --batch_size=2028
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# Current Step = 0
# tcmalloc: large alloc 2839207936 bytes == 0x1e2f2000 @  0x7f38b70d5b6b 0x7f38b70f5379 0x7f386a1fad36 0x7f386a1fb130 0x7f386a1fe84c 0x7f3869ff11df 0x7f386a0f0891 0x7f3869fef470 0x7f38a9a3d8f4 0x5030d5 0x506859 0x501945 0x591461 0x59ebbe 0x507c17 0x504c28 0x501b2e 0x591461 0x59ebbe 0x54d4e2 0x5a730c 0x503073 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x506393 0x634d52 0x634e0a 0x6385c8

# %%
# !python 5_1/q5_1.py --model=TRANSFORMER --batch_size=256
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# Current Step = 0
# Current Step = 1
# Current Step = 2
# Current Step = 3
# Current Step = 4
# Current Step = 5
# Current Step = 6
# Current Step = 7

# %% [markdown]
# # Question 5.2

# %%
# !python 5_2/q5_2.py --model=RNN
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
#   0% 0/1327 [00:00<?, ?it/s]tt:  torch.Size([20])
# outputs shape:  torch.Size([20, 10000])
# test:  tensor(1.)
#
# the array of norms:  [0.00197179 0.00192617 0.00193512 0.00200303 0.00212915 0.00228704
#  0.00248236 0.00271259 0.00293313 0.00313637 0.00337004 0.00362089
#  0.00391885 0.00425679 0.00459294 0.00490232 0.00518623 0.00551822
#  0.00594526 0.00647266 0.00706414 0.0077203  0.0083125  0.0089201
#  0.00959722 0.01042064 0.01159194 0.01306368 0.01514279 0.01797422
#  0.02161927 0.02645301 0.03310054 0.04568441 0.07090913]

# %%
# !python 5_2/q5_2.py --model=GRU
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
#   0% 0/1327 [00:00<?, ?it/s]tt:  torch.Size([20])
# outputs shape:  torch.Size([20, 10000])
# test:  tensor(1.)
#
# the array of norms:  [0.02534319 0.02674412 0.02773407 0.02837631 0.02913363 0.03008293
#  0.03082003 0.03168694 0.03291914 0.03408645 0.03474324 0.03565918
#  0.03626318 0.03719205 0.03844303 0.03949738 0.04085223 0.04214647
#  0.04373473 0.04539054 0.04712309 0.04856103 0.05042056 0.05269585
#  0.05487913 0.05848663 0.06203501 0.06445734 0.06680621 0.07132428
#  0.07548185 0.08070316 0.08778029 0.0941257  0.10029466]

# %%
import numpy as np

rnn = np.array([0.00197179, 0.00192617, 0.00193512, 0.00200303, 0.00212915, 0.00228704,
 0.00248236, 0.00271259, 0.00293313, 0.00313637, 0.00337004, 0.00362089,
 0.00391885, 0.00425679, 0.00459294, 0.00490232, 0.00518623, 0.00551822,
 0.00594526, 0.00647266, 0.00706414, 0.0077203 , 0.00831250, 0.0089201,
 0.00959722, 0.01042064, 0.01159194, 0.01306368, 0.01514279, 0.01797422,
 0.02161927, 0.02645301, 0.03310054, 0.04568441, 0.07090913])

gru = np.array([0.02534319, 0.02674412, 0.02773407, 0.02837631, 0.02913363, 0.03008293,
 0.03082003, 0.03168694, 0.03291914, 0.03408645, 0.03474324, 0.03565918,
 0.03626318, 0.03719205, 0.03844303, 0.03949738, 0.04085223, 0.04214647,
 0.04373473, 0.04539054, 0.04712309, 0.04856103, 0.05042056, 0.05269585,
 0.05487913, 0.05848663, 0.06203501, 0.06445734, 0.06680621, 0.07132428,
 0.07548185, 0.08070316, 0.08778029, 0.0941257, 0.10029466])

import matplotlib.pyplot as plt

plt.plot(range(1,36),(rnn - rnn.min())/(rnn.max() - rnn.min()),"-o",label="RNN")
plt.plot(range(1,36),(gru - gru.min())/(gru.max() - gru.min()),"-o",label="GRU")
plt.title("Evolution of the norm of gardient at every timestep")
plt.xlabel("Timesteps")
plt.legend()
plt.ylabel("Normalised Norm")
# Out:
# Text(0, 0.5, 'Normalised Norm')

# %%
# Question 5.3

# %%
# !python 5_3/q5_3.py --model=RNN --gen_seq_len=35 --n_sequences=10 --seed=111 --temperature=2
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# 0) weisfield meanwhile u.s.s.r. some adjustments restaurants a.g. flooded shocked how lifted this court groups residents added to lin allowing merge fibers acquired june they is down than midyear yet other reliance pricing managing label so telephone
#
# 1) routes backed agricultural evident washington over asking shippers prohibition of trucks officials predict include pertussis computer galvanized relieved itself gop exports spain signed toledo detectors on court supplemental weeks united will peanuts riskier health or what
#
# 2) full-time disobedience regular matter sciences <eos> visitors cause office works on tariffs we main need coup which until regrets successfully turns out <eos> was free bullet allows when ballooning programs were hurt my kids <unk> fujis
#
# ...

# %%
# !python 5_3/q5_3.py --model=RNN --gen_seq_len=70 --n_sequences=10 --seed=112 --temperature=2
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# 0) vice little when unlike republic picked this sweetened generous accounts short barely led music fibers rather unavailable for inflation slump inventories farms he set sales are comply with lucrative risks before competition positions central paris water loans affair indiana restrain speculation attendants worked enormous child parallel abortion the charter switches cardiovascular wives bpca drafted receiving subscriber makes offsetting losses often blessing grab teach supplying given having luck golf brokers while raised
#
# ...

# %%
# !python 5_3/q5_3.py --model=GRU --gen_seq_len=35 --n_sequences=10 --seed=113 --temperature=3
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# 0) absorb crest granting waves of disabilities rocks observers savings law-enforcement 's quote elected chicago document intellectual commitments both champagne lsi vessels activities revival <eos> soared lion hurricane ii purchased with bronx seven shook scared sweet television
#
# 1) bags incredible refinery teams built inspired parties looms assassination uncertainties daily resource ads occur people committees these axa booklets therefore alice channels accounts tele-communications sought drawing journalism lives coopers far more replaced personal helps fired and
#
# ...

# %%
# !python 5_3/q5_3.py --model=GRU --gen_seq_len=70 --n_sequences=10 --seed=114 --temperature=4
# Out:
# WARNING: You are about to run on cpu, and this will likely run out       of memory.
#  You can try setting batch_size=1 to reduce memory usage
# Loading data from data
#   vocabulary size: 10000
# 0) adjusting iras a jewelry corrupt beneficiaries arrange sending propaganda labs etc. continues devote short-term beverage breathing perhaps determine seldom compact on connection brands begin dealings blue-collar belgium incentive regret pennies bicycle dark trans seek ltd. alaskan exploration prosperity midsized characters frame nabisco intensity headaches evenly closely worsen chains preferences packaged-goods engines sheets appearance enfield payment responsibility sleeping set pessimistic adopting counterparts corry chairs courses fleets defend fixed-income cite stimulate templeton mainly
#
# ...
