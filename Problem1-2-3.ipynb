# %% [markdown]
# <h1><center>Assignment 2 - Practical Part</center></h1>
# <center>https://github.com/ai404/ift6135_assignment2</center>
# ___
#
# Team:
#
# * Amine Bellahsen
# * Abderrahim Khalifa
# * Sanae Lotfi
# * Yann Bouteiller
#
# ___
#
# ## Problem 1:
#
# Please find the implementation of the single RNN in the script models.py.
#
# ## Problem 2:
#
# Please find the implementation of the RNN with Gated Reccurent Units in te script models.py.
#
# ## Problem 3:
#
# Please find the implementation of the attention module of a transformer network in the script models.py.
